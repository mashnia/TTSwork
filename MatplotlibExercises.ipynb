# %% [markdown]
# Download the attached CSV file to use as your data set for all exercises. If you are operating within Jupyter Notebooks, the file should be included in your [11_mod_matplotlib/data]  folder, and be accessable from the [17-Exercises] file

# %% [markdown]
# Exercise 1: Read Total profit of all months and show it using a line plot
#
# Total profit data provided for each month. Generated line plot must include the following properties:
#
#     X label name = Month Number
#     Y label name = Total profit

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd

plt.rc('font', size=12) #controls default text size
plt.rc('axes', titlesize=12) #fontsize of the title
plt.rc('axes', labelsize=12) #fontsize of the x and y labels
plt.rc('xtick', labelsize=12) #fontsize of the x tick labels
plt.rc('ytick', labelsize=12) #fontsize of the y tick labels
plt.rc('legend', fontsize=12) #fontsize of the legend

# %%
import pandas as pd

company_sales = pd.read_csv("company_sales_data.csv")

company_sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
fig = plt.figure()
ax = plt.axes()

x = company_sales['month_number']
y = company_sales['total_profit']

plt.plot(x,y)

plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.title("Total Profit Per Month")

plt.show()

# %% [markdown]
# Exercise Question 2: Get Total profit of all months and show line plot with the following Style properties
#
# Generated line plot must include following Style properties:
#
#     Line Style dotted and Line-color should be red
#     Show legend at the lower right location.
#     X label name = Month Number
#     Y label name = Sold units number
#     Add a circle marker.
#     Line marker color as read
#     Line width should be 3

# %%
fig = plt.figure()
ax = plt.axes()

x = company_sales['month_number']
y = company_sales['total_units']

plt.plot(x,y, linestyle = 'dotted', c='red', linewidth=3, marker = 'o', label = 'units')
plt.legend(loc= 'lower right')

plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.title("Units Sold Per Month")

plt.show()

# %% [markdown]
# Exercise Question 3: Read all product sales data and show it using a multiline plot
#
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
x = company_sales['month_number']
a = company_sales['facecream']
b = company_sales['facewash']
c = company_sales['toothpaste']
d = company_sales['bathingsoap']
e = company_sales['shampoo']
f = company_sales['moisturizer']

plt.plot(x, a, label = "face cream")
plt.plot(x, b, label = "face wash")
plt.plot(x, c, label = "toothpaste")
plt.plot(x, d, label = "bathing soap")
plt.plot(x, e, label = "shampoo")
plt.plot(x, f, label = "moisturizer")

plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.title("Units Sold Per Month Per Item")

plt.legend(loc=(1.05,.25))

plt.show()

# %% [markdown]
# Exercise Question 4: Read toothpaste sales data of each month and show it using a scatter plot
#
# Also, add a grid in the plot. gridline style should “–“.

# %%
x1 = company_sales['month_number']
y1 = company_sales['toothpaste']

features = company_sales.toothpaste.T

plt.scatter(x1, y1)

plt.grid(linestyle='dashed')
plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.title("Toothpaste Sales")
# Out:
# Text(0.5, 1.0, 'Toothpaste Sales')

# %% [markdown]
# Exercise Question 5: Read face cream and face wash product sales data and show it using the bar chart
#
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
x = company_sales['month_number']
yy = company_sales['facecream']
yyy = company_sales['facewash']

plt.bar(x+0.4,yy, width=0.4, label='Face Cream')
plt.bar(x+0.4*2,yyy, width=0.4, label='Face Wash')

plt.legend(loc=(1.05,.35))

plt.xticks(x)

plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.title("Face Wash and Face Cream Sales")
# Out:
# Text(0.5, 1.0, 'Face Wash and Face Cream Sales')

# %% [markdown]
# Exercise 6.
#
# Write a script that creates your favorite visual type you have learned about, and display the visual once from within the notebook:​
#
# Explain why you chose your visual type:
#
# Save a copy of the visual once in your choice of vector file formats:​
#
# Save another copy of your visual once in your choice of raster file formats:
#
# Explain which file format you prefer, the vector or the raster, and why:
# This exercise is designed to get you to think objectively and contextually about the differences between file formats. Please note, when you are viewing a vector file format using a computer monitor, you are likely viewing a somewhat "pixelated" version of it still (Pixel Density Resource). File formats are important to think about with consideration for both the scale and type of display being used to view the image.
